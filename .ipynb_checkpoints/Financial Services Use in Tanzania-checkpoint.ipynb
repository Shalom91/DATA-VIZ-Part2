# %% [markdown]
# # Financial Services Use in Tanzania

# %% [markdown]
# The training dataset contains demographic information and what financial services are used by approximately 10,000 individuals across Tanzania. This data was extracted from the FSDT Finscope 2017 survey.
#
# This dataset is the geospatial mapping of all cash outlets in Tanzania in 2012. Cash outlets in this case included commercial banks, community banks, ATMs, microfinance institutions, mobile money agents, bus stations and post offices. This data was collected by FSDT.

# %% [markdown]
# # 1. Examining the dataset

# %%
# import basic data-science packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Open data file to read the first few lines
open('training.csv', 'r').readlines(5)
# Out:
# ['"ID","Q1","Q2","Q3","Q4","Q5","Q6","Q7","Q8_1","Q8_2","Q8_3","Q8_4","Q8_5","Q8_6","Q8_7","Q8_8","Q8_9","Q8_10","Q8_11","Q9","Q10","Q11","Q12","Q13","Q14","Q15","Q16","Q17","Q18","Q19","Latitude","Longitude","mobile_money","savings","borrowing","insurance","mobile_money_classification"\n']

# %%
# Load dataset and explore
tanz_data = pd.read_csv('training.csv')

tanz_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7094 entries, 0 to 7093
# Data columns (total 37 columns):
# ID                             7094 non-null int64
# Q1                             7094 non-null int64
# Q2                             7094 non-null int64
# Q3                             7094 non-null int64
# Q4                             7094 non-null int64
# Q5                             7094 non-null int64
# Q6                             7094 non-null int64
# Q7                             7094 non-null int64
# Q8_1                           7094 non-null int64
# Q8_2                           7094 non-null int64
# Q8_3                           7094 non-null int64
# Q8_4                           7094 non-null int64
# Q8_5                           7094 non-null int64
# Q8_6                           7094 non-null int64
# Q8_7                           7094 non-null int64
# Q8_8                           7094 non-null int64
# ...

# %% [markdown]
# The dataset appears to be a complete dataset. This will be verified in the next section. Furthermore, the ID column contains integer values, which is unusual and indicates that this data-type is invalid.

# %%
# Checking for missing values
tanz_data.isnull().sum()
# Out:
# ID                             0
# Q1                             0
# Q2                             0
# Q3                             0
# Q4                             0
# Q5                             0
# Q6                             0
# Q7                             0
# Q8_1                           0
# Q8_2                           0
# Q8_3                           0
# Q8_4                           0
# Q8_5                           0
# Q8_6                           0
# Q8_7                           0
# Q8_8                           0
# Q8_9                           0
# Q8_10                          0
# Q8_11                          0
# Q9                             0
# Q10                            0
# Q11                            0
# Q12                            0
# Q13                            0
# Q14                            0
# Q15                            0
# Q16                            0
# Q17                            0
# ...

# %% [markdown]
# Conclusion: our dataset has no missing observations.

# %% [markdown]
# ## 2. Descriptive statistics

# %%
# Basic descriptive statistics for the dataset
tanz_data.describe()
# Out:
#                 ID           Q1           Q2           Q3           Q4  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000
# mean   4742.627291    38.239498     1.559910     1.787426     3.060051
# std    2731.120086    16.332148     0.496433     1.165160     1.557779
# min       1.000000    16.000000     1.000000     1.000000     1.000000
# 25%    2397.250000    25.000000     1.000000     1.000000     2.000000
# 50%    4744.500000    35.000000     2.000000     1.000000     3.000000
# 75%    7105.000000    48.000000     2.000000     3.000000     3.000000
# max    9459.000000   100.000000     2.000000     4.000000     8.000000
#
#                 Q5           Q6           Q7         Q8_1         Q8_2  ...  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000  ...
# mean      2.548915     1.840569     1.397942     0.062165     0.630110  ...
# std       1.534257     0.366103     0.489508     0.241472     0.482809  ...
# ...

# %% [markdown]
# ## 3. Graph Representation

# %%
# CLEAN DATASET

# Rename columns
tanz_data = tanz_data.rename(columns={'Q1':'age', 'Q2':'gender', 'Q3':'marital_status', 'Q6':'land_own', 'Q8_1':'wage_income'})
tanz_data = tanz_data.rename(columns={'Q8_2':'trade_income', 'Q8_3':'service_income', 'Q8_4':'piece_income', 'Q8_5':'rent_income', 'Q8_6':'interest_income'})
tanz_data = tanz_data.rename(columns={'Q8_7':'pension_income', 'Q8_8':'welfare_income', 'Q8_9':'dependant_income', 'Q8_10':'expansepaid_income', 'Q8_11':'other_income'})

# Encoding the mobile_money_classification column
tanz_data['mobile_money_classification'] = tanz_data['mobile_money_classification'].astype(str)
new_mm_classification = {'mobile_money_classification': {'0':'no_financial_services', '1':'other_only', '2':'mm_only', '3':'mm_plus'}}
tanz_data.replace(new_mm_classification, inplace=True)

# %%
#display
tanz_data.head()
# Out:
#      ID  age  gender  marital_status  Q4  Q5  land_own  Q7  wage_income  \
# 0  5086   98       2               3   1   1         2   2            0
# 1  1258   40       1               1   3   5         1   1            1
# 2   331   18       2               4   6   3         2   1            0
# 3  6729   50       1               1   3   1         1   1            0
# 4  8671   34       1               1   1   1         2   1            0
#
#    trade_income  ...  Q17  Q18  Q19  Latitude  Longitude  mobile_money  \
# 0             0  ...   -1    4    4 -4.460442  29.811396             0
# 1             0  ...    4    1    4 -6.176438  39.244871             1
# 2             0  ...   -1    1    1 -6.825702  37.652798             1
# 3             0  ...   -1    1    4 -3.372049  35.808307             1
# 4             1  ...   -1    1    4 -7.179645  31.039095             1
#
#    savings  borrowing  insurance  mobile_money_classification
# ...

# %% [markdown]
# ### Financial Services Accessed vs Age

# %%
# Display graph
import seaborn as sns

sns.boxplot(x='mobile_money_classification', y='age', data=tanz_data).set_title('Financial Services Accessed vs Age')
# Out:
# Text(0.5, 1.0, 'Financial Services Accessed vs Age')

# %% [markdown]
# 1. No_financial_services: Individuals who do not use mobile money, do not save, do not have credit, and do not have insurance
#
# 2. Other_only: Individuals who do not use mobile money, but do use at least one of the other financial services (savings, credit, insurance)
#
# 3. Mm_only: Individuals who use mobile money only
#
# 4. Mm_plus: Individuals who use mobile money and also use at least one of the other financial services (savings, credit, insurance)

# %% [markdown]
# ### Financial Services Accessed vs Gender

# %%
# frequency table
mmc_gender_table = pd.crosstab(index=tanz_data['mobile_money_classification'], columns=tanz_data['gender'])

mmc_gender_table
# Out:
# gender                          1     2
# mobile_money_classification
# mm_only                       354   450
# mm_plus                      1605  1521
# no_financial_services         468   918
# other_only                    695  1083

# %%
# plot graph
mmc_gender_table.plot(kind='bar', stacked=True).set_title('Financial Services Accessed vs Gender')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# Gender: 1 = Male
#         2 = Female

# %% [markdown]
# ### Financial Services Accessed vs Marital Status

# %%
# frequency table
mmc_marital_table = pd.crosstab(index=tanz_data['mobile_money_classification'], columns=tanz_data['marital_status'])

mmc_marital_table
# Out:
# marital_status                  1    2    3    4
# mobile_money_classification
# mm_only                       463   94   61  186
# mm_plus                      2087  289  197  553
# no_financial_services         782  127  235  242
# other_only                   1216  177  185  200

# %%
# plot graph
mmc_marital_table.plot(kind='bar', stacked=True).set_title('Financial Services Accessed vs Marital Status')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# Marital Status: 1 = Married
#                 2 = Divorced
#                 3 = Widowed
#                 4 = Single/never married

# %% [markdown]
# ### Financial Services Accessed vs Land Ownership

# %%
# frequency table
mmc_land_table = pd.crosstab(index=tanz_data['mobile_money_classification'], columns=tanz_data['land_own'])

mmc_land_table
# Out:
# land_own                       1     2
# mobile_money_classification
# mm_only                      105   699
# mm_plus                      647  2479
# no_financial_services        134  1252
# other_only                   245  1533

# %%
# plot graph
mmc_land_table.plot(kind='bar', stacked=True).set_title('Financial Services Accessed vs Land Ownership')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  1 = Yes  2 = No

# %% [markdown]
# ### Financial Services Accessed vs Type of Income

# %%
# frequency table
mmc_income1_table = pd.crosstab(index=tanz_data['mobile_money_classification'], columns=tanz_data['wage_income'])

# %%
# plot graph
mmc_income1_table.plot(kind='bar', stacked=True).set_title('Financial Services Accessed vs Wage Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No
#              1 = Yes

# %%
# frequency table
mmc_income2_table = pd.crosstab(index=tanz_data['mobile_money_classification'], columns=tanz_data['trade_income'])

# %%
# plot graph
mmc_income2_table.plot(kind='bar', stacked=True).set_title('Financial Services Accessed vs Trade Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %%
# frequency table
mmc_income3_table = pd.crosstab(index=tanz_data['mobile_money_classification'], columns=tanz_data['service_income'])

# %%
# plot graph
mmc_income3_table.plot(kind='bar', stacked=True).set_title('Financial Services Accessed vs Service Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %%
# frequency table
mmc_income4_table = pd.crosstab(index=tanz_data['mobile_money_classification'], columns=tanz_data['piece_income'])

# plot graph
mmc_income4_table.plot(kind='bar', stacked=True).set_title('Financial Services Accessed vs Piece Job Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %%
# frequency table
mmc_income5_table = pd.crosstab(index=tanz_data['mobile_money_classification'], columns=tanz_data['rent_income'])

# plot graph
mmc_income5_table.plot(kind='bar', stacked=True).set_title('Financial Services Accessed vs Rental Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %%
# frequency table
mmc_income6_table = pd.crosstab(index=tanz_data['mobile_money_classification'], columns=tanz_data['interest_income'])

# plot graph
mmc_income6_table.plot(kind='bar', stacked=True).set_title('Financial Services Accessed vs Interest Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %%
# frequency table
mmc_income7_table = pd.crosstab(index=tanz_data['mobile_money_classification'], columns=tanz_data['pension_income'])

# plot graph
mmc_income7_table.plot(kind='bar', stacked=True).set_title('Financial Services Accessed vs Pension Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %%
# frequency table
mmc_income8_table = pd.crosstab(index=tanz_data['mobile_money_classification'], columns=tanz_data['welfare_income'])

# plot graph
mmc_income8_table.plot(kind='bar', stacked=True).set_title('Financial Services Accessed vs Welfare Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %%
# frequency table
mmc_income9_table = pd.crosstab(index=tanz_data['mobile_money_classification'], columns=tanz_data['dependant_income'])

# plot graph
mmc_income9_table.plot(kind='bar', stacked=True).set_title('Financial Services Accessed vs Dependant Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %%
# frequency table
mmc_income10_table = pd.crosstab(index=tanz_data['mobile_money_classification'], columns=tanz_data['expansepaid_income'])

# plot graph
mmc_income10_table.plot(kind='bar', stacked=True).set_title('Financial Services Accessed vs Expense Paid On Behalf')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %%
# frequency table
mmc_income11_table = pd.crosstab(index=tanz_data['mobile_money_classification'], columns=tanz_data['other_income'])

# plot graph
mmc_income11_table.plot(kind='bar', stacked=True).set_title('Financial Services Accessed vs Other Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %% [markdown]
# # 4. Graph Representation: Pt. 2

# %%
# Rename column header
tanz_data = tanz_data.rename(columns={'Q16':'mobile_money_usage'})

# Encoding the mobile_money_usage column
tanz_data['mobile_money_usage'] = tanz_data['mobile_money_usage'].astype(str)
new_mm_classification = {'mobile_money_usage': {'-1':'no_applicable', '1':'never', '2':'daily', '3':'weekly', '4':'monthly', '5':'less_than_monthly'}}
tanz_data.replace(new_mm_classification, inplace=True)

# %% [markdown]
# ### Frequency of Mobile Money Usage vs Age

# %%
# Display graph
sns.boxplot(x='mobile_money_usage', y='age', data=tanz_data).set_title('Frequency of Mobile Money Usage vs Age')
# Out:
# Text(0.5, 1.0, 'Frequency of Mobile Money Usage vs Age')

# %% [markdown]
# ### Frequency of Mobile Money Usage vs Gender

# %%
# frequency table
mmu_gender_table = pd.crosstab(index=tanz_data['mobile_money_usage'], columns=tanz_data['gender'])

# plot graph
mmu_gender_table.plot(kind='bar', stacked=True).set_title('Frequency of Mobile Money Usage vs Gender')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# Gender: 1 = Male
#         2 = Female

# %% [markdown]
# ### Frequency of Mobile Money Usage vs Marital Status

# %%
# frequency table
mmu_marital_table = pd.crosstab(index=tanz_data['mobile_money_usage'], columns=tanz_data['marital_status'])

# plot graph
mmu_marital_table.plot(kind='bar', stacked=True).set_title('Frequency of Mobile Money Usage vs Marital Status')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# Marital Status: 1 = Married 2 = Divorced 3 = Widowed 4 = Single/never married

# %% [markdown]
# ### Frequency of Mobile Money Usage vs Land Ownership

# %%
# frequency table
mmu_land_table = pd.crosstab(index=tanz_data['mobile_money_usage'], columns=tanz_data['land_own'])

# plot graph
mmu_land_table.plot(kind='bar', stacked=True).set_title('Frequency of Mobile Money Usage vs Land Ownership')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  1 = Yes 2 = No

# %% [markdown]
# ### Frequency of Mobile Money Usage vs Type of Income

# %%
# frequency table
mmu_income1_table = pd.crosstab(index=tanz_data['mobile_money_usage'], columns=tanz_data['wage_income'])

# plot graph
mmu_income1_table.plot(kind='bar', stacked=True).set_title('Frequency of Mobile Money Usage vs Wage Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %%
# frequency table
mmu_income2_table = pd.crosstab(index=tanz_data['mobile_money_usage'], columns=tanz_data['trade_income'])

# plot graph
mmu_income2_table.plot(kind='bar', stacked=True).set_title('Frequency of Mobile Money Usage vs Trade Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %%
# frequency table
mmu_income3_table = pd.crosstab(index=tanz_data['mobile_money_usage'], columns=tanz_data['service_income'])

# plot graph
mmu_income3_table.plot(kind='bar', stacked=True).set_title('Frequency of Mobile Money Usage vs Service Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %%
# frequency table
mmu_income4_table = pd.crosstab(index=tanz_data['mobile_money_usage'], columns=tanz_data['piece_income'])

# plot graph
mmu_income4_table.plot(kind='bar', stacked=True).set_title('Frequency of Mobile Money Usage vs Piece Job Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %%
# frequency table
mmu_income5_table = pd.crosstab(index=tanz_data['mobile_money_usage'], columns=tanz_data['rent_income'])

# plot graph
mmu_income5_table.plot(kind='bar', stacked=True).set_title('Frequency of Mobile Money Usage vs Rental Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %%
# frequency table
mmu_income6_table = pd.crosstab(index=tanz_data['mobile_money_usage'], columns=tanz_data['interest_income'])

# plot graph
mmu_income6_table.plot(kind='bar', stacked=True).set_title('Frequency of Mobile Money Usage vs Interest Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %%
# frequency table
mmu_income7_table = pd.crosstab(index=tanz_data['mobile_money_usage'], columns=tanz_data['pension_income'])

# plot graph
mmu_income7_table.plot(kind='bar', stacked=True).set_title('Frequency of Mobile Money Usage vs Pension Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %%
# frequency table
mmu_income8_table = pd.crosstab(index=tanz_data['mobile_money_usage'], columns=tanz_data['welfare_income'])

# plot graph
mmu_income8_table.plot(kind='bar', stacked=True).set_title('Frequency of Mobile Money Usage vs Welfare Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %%
# frequency table
mmu_income9_table = pd.crosstab(index=tanz_data['mobile_money_usage'], columns=tanz_data['dependant_income'])

# plot graph
mmu_income9_table.plot(kind='bar', stacked=True).set_title('Frequency of Mobile Money Usage vs Dependant Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %%
# frequency table
mmu_income10_table = pd.crosstab(index=tanz_data['mobile_money_usage'], columns=tanz_data['expansepaid_income'])

# plot graph
mmu_income10_table.plot(kind='bar', stacked=True).set_title('Frequency of Mobile Money Usage vs Expenses Paid for')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %%
# frequency table
mmu_income11_table = pd.crosstab(index=tanz_data['mobile_money_usage'], columns=tanz_data['other_income'])

# plot graph
mmu_income11_table.plot(kind='bar', stacked=True).set_title('Frequency of Mobile Money Usage vs Other Income')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  0 = No 1 = Yes

# %% [markdown]
# # 4. Geographic Distribution Map

# %%
# install gmplot
# !pip install gmplot
# Out:
# ...
#      |████████████████████████████████| 122kB 290kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 61kB 431kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 61kB 176kB/s eta 0:00:011
# ...
#      |████████████████████████████████| 133kB 286kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 143kB 194kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 163kB 236kB/s eta 0:00:01
# ...
#   Created wheel for gmplot: filename=gmplot-1.2.0-cp37-none-any.whl size=143765 sha256=0db0819604416aaa0e80bcf0b6ef408e80460a669deb867b1ca2dcadfd6536cc
#   Stored in directory: /home/molash/.cache/pip/wheels/81/6a/76/4dd6a7cc310ba765894159ee84871e8cd55221d82ef14b81a1
# Successfully built gmplot
# ...

# %%
# Import libraries
import gmplot

# declare the center of the map and zoom accuracy
gmap = gmplot.GoogleMapPlotter(-6, 35, 10)

# plot heatmap
gmap.heatmap(tanz_data['Latitude'], tanz_data['Longitude'])


gmap.draw('my_heatmap.html')

# %% [markdown]
# # 4. Conclusion
